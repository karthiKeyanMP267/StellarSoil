# %%
# chatbot_gemini.py
'''
import os
import google.generativeai as genai

# Initialize the model
API_KEY = "AIzaSyBn8KV1fDGv1SQpreTfQKFNoTcWHDeLRQI"
genai.configure(api_key=API_KEY)


def chat_with_gemini():
    """
    Starts a simple command-line chat session with the Gemini 1.5 Flash model.
    """
    print("=== Gemini 1.5 Flash Chatbot ===")
    print("Type 'exit' to quit.\n")

    # The use of `GenerativeModel` and `start_chat` is better for a conversational
    # chatbot than the deprecated `generate_text` function.
    model = genai.GenerativeModel('gemini-1.5-flash')
    chat_session = model.start_chat(history=[])

    while True:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            print("Exiting chat...")
            break
        
        try:
            response = chat_session.send_message(user_input)
            print("Bot:", response.text)
        except Exception as e:
            print(f"Error: {e}")

if __name__ == "__main__":
    chat_with_gemini()
    '''
# Out:
# '\nimport os\nimport google.generativeai as genai\n\n# Initialize the model\nAPI_KEY = "AIzaSyBn8KV1fDGv1SQpreTfQKFNoTcWHDeLRQI"\ngenai.configure(api_key=API_KEY)\n\n\ndef chat_with_gemini():\n    """\n    Starts a simple command-line chat session with the Gemini 1.5 Flash model.\n    """\n    print("=== Gemini 1.5 Flash Chatbot ===")\n    print("Type \'exit\' to quit.\n")\n\n    # The use of `GenerativeModel` and `start_chat` is better for a conversational\n    # chatbot than the deprecated `generate_text` function.\n    model = genai.GenerativeModel(\'gemini-1.5-flash\')\n    chat_session = model.start_chat(history=[])\n\n    while True:\n        user_input = input("You: ")\n        if user_input.lower() == \'exit\':\n            print("Exiting chat...")\n            break\n        \n        try:\n            response = chat_session.send_message(user_input)\n            print("Bot:", response.text)\n        except Exception as e:\n            print(f"Error: {e}")\n\nif __name__ == 
# ...

# %%
# !pip install flask pyngrok && ngrok config add-authtoken YOUR_NGROK_AUTH_TOKEN && python - <<'EOF'
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `EOF')
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
'''!pip install flask pyngrok && \
ngrok config add-authtoken 2thd7cCsNZHiMDXtyNVKeifH13C_4DzXDA37X2wXDSbnR93iR && \
python - <<'EOF'
from flask import Flask
from pyngrok import ngrok

app = Flask(__name__)

@app.route("/")
def home():
    return "Hello from Kaggle via ngrok!"

# Open ngrok tunnel on port 5000
public_url = ngrok.connect(5000)
print("Public URL:", public_url)

app.run(host="0.0.0.0", port=5000)
EOF
'''
# Out:
# '!pip install flask pyngrok && ngrok config add-authtoken 2thd7cCsNZHiMDXtyNVKeifH13C_4DzXDA37X2wXDSbnR93iR && python - <<\'EOF\'\nfrom flask import Flask\nfrom pyngrok import ngrok\n\napp = Flask(__name__)\n\n@app.route("/")\ndef home():\n    return "Hello from Kaggle via ngrok!"\n\n# Open ngrok tunnel on port 5000\npublic_url = ngrok.connect(5000)\nprint("Public URL:", public_url)\n\napp.run(host="0.0.0.0", port=5000)\nEOF\n'

# %%
# !git clone https://github.com/PRABU-21/ngroktest.git
# Out:
# Cloning into 'ngroktest'...
# remote: Enumerating objects: 190, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 190 (delta 2), reused 0 (delta 0), pack-reused 181 (from 4)
# Receiving objects: 100% (190/190), 154.75 KiB | 2.92 MiB/s, done.
# Resolving deltas: 100% (92/92), done.

# %%
# %cd ngroktest
# Out:
# /kaggle/working/ngroktest

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 74.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 104.0 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !ngrok config add-authtoken "2thd7cCsNZHiMDXtyNVKeifH13C_4DzXDA37X2wXDSbnR93iR"
#&& \
#python - <<'EOF'
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !python main.py
# Out:
# 2025-09-20 10:34:26.947909: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758364467.312015     133 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758364467.415186     133 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
# config_sentence_transformers.json: 100%|████████| 116/116 [00:00<00:00, 965kB/s]
# README.md: 10.5kB [00:00, 41.5MB/s]
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 263kB/s]
# config.json: 100%|█████████████████████████████| 612/612 [00:00<00:00, 5.97MB/s]
# ...
